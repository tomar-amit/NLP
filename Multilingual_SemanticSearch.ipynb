# %%
# !pip install sentence_transformers

# %%
from termcolor import colored
from sentence_transformers import SentenceTransformer, models, util
import torch

# %% [markdown]
# <h3>SentenceTransformers Multilingual-Models </h3>
# <p> Ref- https://www.sbert.net/examples/training/multilingual/README.html#multilingual-models </p>
#
# <h4> Performance </h4>
#
#   <table><tr>
#     <th>Model</th>
#     <th>AR-AR</th>
#     <th>AR-EN</th>
#     <th>ES-ES</th>
#     <th>ES-EN</th>
#     <th>EN-EN</th>
#     <th>TR-EN</th>
#     <th>EN-DE</th>
#     <th>FR-EN</th>
#     <th>IT-EN</th>
#     <th>NL-EN</th>
#     <th>Average</th>
#   </tr>
#   <tr>
#     <td>XLM-RoBERTa mean pooling </td>
#     <td align="center">25.7</td>
#     <td align="center">17.4</td>
#     <td align="center">51.8</td>
#     <td align="center">10.9</td>
#     <td align="center">50.7</td>
#     <td align="center">9.2</td>
#     <td align="center">21.3</td>
#     <td align="center">16.6</td>
#     <td align="center">22.9</td>
#     <td align="center">26.0</td>
#     <td align="center">25.2</td>
#   </tr>
#   <tr>
#     <td>mBERT mean pooling </td>
#     <td align="center">50.9</td>
#     <td align="center">16.7</td>
#     <td align="center">56.7</td>
#     <td align="center">21.5</td>
#     <td align="center">54.4</td>
#     <td align="center">16.0</td>
#     <td align="center">33.9</td>
#     <td align="center">33.0</td>
#     <td align="center">34.0</td>
#     <td align="center">35.6</td>
#     <td align="center">35.3</td>
#   </tr>
#   <tr>
#     <td>LASER</td>
#     <td align="center">68.9</td>
#     <td align="center">66.5</td>
#     <td align="center">79.7</td>
#     <td align="center">57.9</td>
#     <td align="center">77.6</td>
#     <td align="center">72.0</td>
#     <td align="center">64.2</td>
#     <td align="center">69.1</td>
#     <td align="center">70.8</td>
#     <td align="center">68.5</td>
#     <td align="center">69.5</td>
#   </tr>
#   <tr>
#     <td colspan="12"><b>Sentence Transformer Models</b></td>
#   </tr>
#   <tr>
#   <td>distiluse-base-multilingual-cased</td>
#     <td align="center">75.9</td>
#     <td align="center">77.6</td>
#     <td align="center">85.3</td>
#     <td align="center">78.7</td>
#     <td align="center">85.4</td>
#     <td align="center">75.5</td>
#     <td align="center">80.3</td>
#     <td align="center">80.2</td>
#     <td align="center">80.5</td>
#     <td align="center">81.7</td>
#     <td align="center">80.1</td>
#     </tr>
# </table>
#
#
# <h4> Usage </h4>
#
# ```
# from sentence_transformers import SentenceTransformer
# model_name = "distiluse-base-multilingual-cased"
# embedder = SentenceTransformer(model_name)
# embeddings = embedder.encode(['Hello World', 'Hallo Welt', 'Hola mundo'])
# print(embeddings)
# ```

# %% [markdown]
# <h3> Load multilingual BERT model in SentenceTransformer </h3>
#
# ```
# # from sentence_transformers import models
# from sentence_transformers import SentenceTransformer, models
#
# #Multilingual Model
# model_name = 'bert-base-multilingual-uncased'
#
# # Use BERT for mapping tokens to embeddings
# word_embedding_model = models.Transformer(model_name)
# # word_embedding_model = models.Transformer('bert-base-uncased', max_seq_length=256)
#
# # Apply mean pooling to get one fixed sized sentence vector
# pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(),
#                                pooling_mode_mean_tokens=True,
#                                pooling_mode_cls_token=False,
#                                pooling_mode_max_tokens=False)
# model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# ```

# %% [markdown]
# ## Test SentenceTransformer Multilingual Model

# %%
from sentence_transformers import SentenceTransformer
model_name = 'distiluse-base-multilingual-cased'
embedder = SentenceTransformer(model_name)
# embeddings = embedder.encode(['list of sentences'])
# print(embeddings)

# %%
corpus = ['A man is eating food.',
          'A man is eating a piece of bread.',
          'The girl is carrying a baby.',
          'A man is riding a horse.',
          'A woman is playing violin.',
          'Two men pushed carts through the woods.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'A cheetah is running behind its prey.',
          'apple',
          'mango',
          'understanding',
          'एक आदमी खाना खा रहा है।',
          'एक आदमी रोटी का टुकड़ा खा रहा है।',
          'लड़की एक बच्चे को ले जा रही है।',
          'एक आदमी घोड़े की सवारी कर रहा है।',
          'एक महिला वायलिन बजा रही है।',
          'दो आदमियों ने गाड़ियों को जंगल में धकेला।',
          'एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है।',
          'एक बंदर ढोल बजा रहा है।',
          'एक चीता अपने शिकार के पीछे भाग रहा है।',
          'सेब',
          'आम',
          'समझ'
           ]

# %%
#encode the corpus or create the sentence embeddings
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# %%
#Test Data
queries = ['एक आदमी खाना खा रहा है।',
          'एक आदमी रोटी का टुकड़ा खा रहा है।',
          'लड़की एक बच्चे को ले जा रही है।',
          'एक आदमी घोड़े की सवारी कर रहा है।',
          'एक महिला वायलिन बजा रही है।',
          'दो आदमियों ने गाड़ियों को जंगल में धकेला।',
          'एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है।',
          'एक बंदर ढोल बजा रहा है।',
          'एक बंदर गाना गा रहा है।',
          'एक बंदर खाना खा रहा है।',
          'एक चीता अपने शिकार के पीछे भाग रहा है।',
          'सेब',
          'आम',
          'समझ',
           "Is monkey an animal?",
           ]

# %%
top_k = min(5, len(corpus))
for i, query in enumerate(queries):
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n======================")
    print(colored(f"{i}. Query: {query}", 'red'))
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(colored(f"{corpus[idx]} Score: {score})", 'green'))
# Out:
# ======================
# 0. Query: एक आदमी खाना खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी खाना खा रहा है। Score: 0.9999997019767761)
# A man is eating food. Score: 0.9736140966415405)
# A man is eating a piece of bread. Score: 0.7029650211334229)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.6472431421279907)
# A man is riding a horse. Score: 0.37016773223876953)
#
# ======================
# 1. Query: एक आदमी रोटी का टुकड़ा खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.9999998807907104)
# A man is eating a piece of bread. Score: 0.9618503451347351)
# एक आदमी खाना खा रहा है। Score: 0.6472431421279907)
# A man is eating food. Score: 0.5999749898910522)
# A monkey is playing drums. Score: 0.3435114026069641)
#
# ======================
# 2. Query: लड़की एक बच्चे को ले जा रही है।
#
# Top 5 most similar sentences in corpus:
# लड़की एक बच्चे को ले जा रही है। Score: 0.9999996423721313)
# The girl is carrying a baby. Score: 0.8273077011108398)
# एक महिला वायलिन बजा रही है। Score: 0.38620489835739136)
# A woman is playing violin. Score: 0.28301066160202026)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.2358277440071106)
#
# ======================
# 3. Query: एक आदमी घोड़े की सवारी कर रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी घोड़े की सवारी कर रहा है। Score: 1.0000001192092896)
# A man is riding a horse. Score: 0.9521925449371338)
# A man is riding a white horse on an enclosed ground. Score: 0.6942161917686462)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.5960196852684021)
# A cheetah is running behind its prey. Score: 0.35042160749435425)
#
# ======================
# 4. Query: एक महिला वायलिन बजा रही है।
#
# Top 5 most similar sentences in corpus:
# एक महिला वायलिन बजा रही है। Score: 1.0)
# A woman is playing violin. Score: 0.7304663062095642)
# A monkey is playing drums. Score: 0.3949210047721863)
# लड़की एक बच्चे को ले जा रही है। Score: 0.3862048387527466)
# The girl is carrying a baby. Score: 0.3332030177116394)
#
# ======================
# 5. Query: दो आदमियों ने गाड़ियों को जंगल में धकेला।
#
# Top 5 most similar sentences in corpus:
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 1.0000001192092896)
# Two men pushed carts through the woods. Score: 0.7842774391174316)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.3272843360900879)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.31166312098503113)
# A man is riding a horse. Score: 0.27870413661003113)
#
# ======================
# 6. Query: एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.9999994039535522)
# A man is riding a white horse on an enclosed ground. Score: 0.9353652596473694)
# A man is riding a horse. Score: 0.6020223498344421)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.5960196256637573)
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 0.27581000328063965)
#
# ======================
# 7. Query: एक बंदर ढोल बजा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.9999997019767761)
# A monkey is playing drums. Score: 0.7328723669052124)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.5113229155540466)
# सेब Score: 0.43044334650039673)
# apple Score: 0.4163024127483368)
#
# ======================
# 8. Query: एक बंदर गाना गा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.7176181077957153)
# A monkey is playing drums. Score: 0.6281834840774536)
# सेब Score: 0.38138580322265625)
# apple Score: 0.3707790970802307)
# A woman is playing violin. Score: 0.3521662950515747)
#
# ======================
# 9. Query: एक बंदर खाना खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.7672802209854126)
# एक आदमी खाना खा रहा है। Score: 0.6558529138565063)
# A man is eating food. Score: 0.6128974556922913)
# A monkey is playing drums. Score: 0.5784957408905029)
# A man is eating a piece of bread. Score: 0.4914679527282715)
#
# ======================
# 10. Query: एक चीता अपने शिकार के पीछे भाग रहा है।
#
# Top 5 most similar sentences in corpus:
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 1.000000238418579)
# A cheetah is running behind its prey. Score: 0.7770971059799194)
# एक बंदर ढोल बजा रहा है। Score: 0.5113228559494019)
# A monkey is playing drums. Score: 0.35582593083381653)
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 0.31166303157806396)
#
# ======================
# 11. Query: सेब
#
# Top 5 most similar sentences in corpus:
# सेब Score: 1.000000238418579)
# apple Score: 0.9306411743164062)
# mango Score: 0.6348576545715332)
# आम Score: 0.5743615031242371)
# एक बंदर ढोल बजा रहा है। Score: 0.4304434061050415)
#
# ======================
# 12. Query: आम
#
# Top 5 most similar sentences in corpus:
# आम Score: 1.0000001192092896)
# सेब Score: 0.5743615031242371)
# समझ Score: 0.547327995300293)
# mango Score: 0.4898306727409363)
# apple Score: 0.45747822523117065)
#
# ======================
# 13. Query: समझ
#
# Top 5 most similar sentences in corpus:
# समझ Score: 1.0000004768371582)
# understanding Score: 0.6961339712142944)
# आम Score: 0.5473280549049377)
# सेब Score: 0.33043819665908813)
# mango Score: 0.2637074589729309)
#
# ======================
# 14. Query: Is monkey an animal?
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.6638107299804688)
# A monkey is playing drums. Score: 0.501065731048584)
# apple Score: 0.32035690546035767)
# सेब Score: 0.32017767429351807)
# mango Score: 0.3096903860569)

# %%
gujrati = ['એક માણસ ખોરાક ખાઈ રહ્યો છે.',
           'એક માણસ બ્રેડનો ટુકડો ખાઈ રહ્યો છે.',
           'છોકરી બાળકને લઈ જઈ રહી છે.',
           'એક માણસ ઘોડા પર સવાર છે.',
           'એક સ્ત્રી વાયોલિન વગાડી રહી છે.',
           'બે માણસોએ ગાડીઓને જંગલમાં ધકેલી દીધી.',
           'એક માણસ બંધ જમીન પર સફેદ ઘોડા પર સવાર છે.',
           'એક વાંદરો ઢોલ વગાડી રહ્યો છે.',
           'ચિત્તો તેના શિકારની પાછળ દોડે છે.',
           'સફરજન',
           'કેરી',
           'સમજવુ']

eng =    ['A man is eating food.',
          'A man is eating a piece of bread.',
          'The girl is carrying a baby.',
          'A man is riding a horse.',
          'A woman is playing violin.',
          'Two men pushed carts through the woods.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'A cheetah is running behind its prey.',
          'apple',
          'mango',
          'understanding']

# %%
top_k = min(5, len(corpus))
for i, query in enumerate(gujrati):
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n======================")
    print(colored(f"{i}. Query: {query}", 'red'))
    print(colored(f"{i}. Translation of query: {eng[i]}", 'red'))
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(colored(f"{corpus[idx]} Score: {score})", 'green'))
# Out:
# ======================
# 0. Query: એક માણસ ખોરાક ખાઈ રહ્યો છે.
# 0. Translation of query: A man is eating food.
#
# Top 5 most similar sentences in corpus:
# एक आदमी खाना खा रहा है। Score: 0.8792285919189453)
# A man is eating food. Score: 0.8619061708450317)
# A man is eating a piece of bread. Score: 0.6823359727859497)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.6788792610168457)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.32669737935066223)
#
# ======================
# 1. Query: એક માણસ બ્રેડનો ટુકડો ખાઈ રહ્યો છે.
# 1. Translation of query: A man is eating a piece of bread.
#
# Top 5 most similar sentences in corpus:
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.5257009863853455)
# A man is eating a piece of bread. Score: 0.47255370020866394)
# एक बंदर ढोल बजा रहा है। Score: 0.37435203790664673)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.37368011474609375)
# एक आदमी खाना खा रहा है। Score: 0.36608418822288513)
#
# ======================
# 2. Query: છોકરી બાળકને લઈ જઈ રહી છે.
# 2. Translation of query: The girl is carrying a baby.
#
# Top 5 most similar sentences in corpus:
# लड़की एक बच्चे को ले जा रही है। Score: 0.835120439529419)
# The girl is carrying a baby. Score: 0.6807812452316284)
# एक महिला वायलिन बजा रही है। Score: 0.3356500566005707)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.24178098142147064)
# A woman is playing violin. Score: 0.2090017944574356)
#
# ======================
# 3. Query: એક માણસ ઘોડા પર સવાર છે.
# 3. Translation of query: A man is riding a horse.
#
# Top 5 most similar sentences in corpus:
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.4404386281967163)
# A man is eating a piece of bread. Score: 0.4318771958351135)
# एक आदमी खाना खा रहा है। Score: 0.39074796438217163)
# एक बंदर ढोल बजा रहा है। Score: 0.37743479013442993)
# A man is riding a horse. Score: 0.37084054946899414)
#
# ======================
# 4. Query: એક સ્ત્રી વાયોલિન વગાડી રહી છે.
# 4. Translation of query: A woman is playing violin.
#
# Top 5 most similar sentences in corpus:
# एक महिला वायलिन बजा रही है। Score: 0.6897846460342407)
# A woman is playing violin. Score: 0.4494016766548157)
# लड़की एक बच्चे को ले जा रही है। Score: 0.3590492308139801)
# The girl is carrying a baby. Score: 0.31826403737068176)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.2841252088546753)
#
# ======================
# 5. Query: બે માણસોએ ગાડીઓને જંગલમાં ધકેલી દીધી.
# 5. Translation of query: Two men pushed carts through the woods.
#
# Top 5 most similar sentences in corpus:
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 0.9013137221336365)
# Two men pushed carts through the woods. Score: 0.7448333501815796)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.3247010111808777)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.2525289058685303)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.2277349978685379)
#
# ======================
# 6. Query: એક માણસ બંધ જમીન પર સફેદ ઘોડા પર સવાર છે.
# 6. Translation of query: A man is riding a white horse on an enclosed ground.
#
# Top 5 most similar sentences in corpus:
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.46986210346221924)
# A man is riding a white horse on an enclosed ground. Score: 0.41730043292045593)
# Two men pushed carts through the woods. Score: 0.376822829246521)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.36620765924453735)
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 0.3617708086967468)
#
# ======================
# 7. Query: એક વાંદરો ઢોલ વગાડી રહ્યો છે.
# 7. Translation of query: A monkey is playing drums.
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.6839914321899414)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.5900706052780151)
# A cheetah is running behind its prey. Score: 0.49611565470695496)
# A monkey is playing drums. Score: 0.43329793214797974)
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 0.3360822796821594)
#
# ======================
# 8. Query: ચિત્તો તેના શિકારની પાછળ દોડે છે.
# 8. Translation of query: A cheetah is running behind its prey.
#
# Top 5 most similar sentences in corpus:
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.458243727684021)
# A cheetah is running behind its prey. Score: 0.44760358333587646)
# लड़की एक बच्चे को ले जा रही है। Score: 0.3428332507610321)
# एक बंदर ढोल बजा रहा है। Score: 0.3130389451980591)
# एक महिला वायलिन बजा रही है। Score: 0.30332323908805847)
#
# ======================
# 9. Query: સફરજન
# 9. Translation of query: apple
#
# Top 5 most similar sentences in corpus:
# सेब Score: 0.8524817228317261)
# apple Score: 0.7747871279716492)
# आम Score: 0.6710116863250732)
# mango Score: 0.6304656863212585)
# समझ Score: 0.3598095774650574)
#
# ======================
# 10. Query: કેરી
# 10. Translation of query: mango
#
# Top 5 most similar sentences in corpus:
# आम Score: 0.491926908493042)
# समझ Score: 0.40966272354125977)
# सेब Score: 0.35613489151000977)
# mango Score: 0.2841234505176544)
# apple Score: 0.2690465450286865)
#
# ======================
# 11. Query: સમજવુ
# 11. Translation of query: understanding
#
# Top 5 most similar sentences in corpus:
# समझ Score: 0.9353191256523132)
# understanding Score: 0.5733321905136108)
# आम Score: 0.4638802111148834)
# सेब Score: 0.2709510922431946)
# mango Score: 0.21247448027133942)

# %% [markdown]
# ## Test Multilingual BERT Model

# %%
# from sentence_transformers import models
from sentence_transformers import SentenceTransformer, models

# Multilingual Model
model_name = 'bert-base-multilingual-uncased'

# Use BERT for mapping tokens to embeddings
word_embedding_model = models.Transformer(model_name)
# word_embedding_model = models.Transformer('bert-base-uncased', max_seq_length=256)

# Apply mean pooling to get one fixed sized sentence vector
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(),
                               pooling_mode_mean_tokens=True,
                               pooling_mode_cls_token=False,
                               pooling_mode_max_tokens=False)
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
corpus_embeddings_ = model.encode(corpus, convert_to_tensor=True)

# %%
top_k = min(5, len(corpus))
for i, query in enumerate(queries):
    query_embedding = model.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings_)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n======================")
    print(colored(f"{i}. Query: {query}", 'red'))
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(colored(f"{corpus[idx]} Score: {score})", 'green'))
# Out:
# ======================
# 0. Query: एक आदमी खाना खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी खाना खा रहा है। Score: 1.0)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8767616152763367)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.8630039095878601)
# एक महिला वायलिन बजा रही है। Score: 0.8284913897514343)
# एक बंदर ढोल बजा रहा है। Score: 0.8233563899993896)
#
# ======================
# 1. Query: एक आदमी रोटी का टुकड़ा खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 1.0000008344650269)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.9081702828407288)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.8989201188087463)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.8853155374526978)
# एक आदमी खाना खा रहा है। Score: 0.8767614364624023)
#
# ======================
# 2. Query: लड़की एक बच्चे को ले जा रही है।
#
# Top 5 most similar sentences in corpus:
# लड़की एक बच्चे को ले जा रही है। Score: 0.9999997019767761)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.8680552244186401)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.8541032671928406)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8507050275802612)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.8323653936386108)
#
# ======================
# 3. Query: एक आदमी घोड़े की सवारी कर रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी घोड़े की सवारी कर रहा है। Score: 1.0000007152557373)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.9131028652191162)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.908170223236084)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.8981736898422241)
# लड़की एक बच्चे को ले जा रही है। Score: 0.8680552244186401)
#
# ======================
# 4. Query: एक महिला वायलिन बजा रही है।
#
# Top 5 most similar sentences in corpus:
# एक महिला वायलिन बजा रही है। Score: 0.9999996423721313)
# एक बंदर ढोल बजा रहा है। Score: 0.8327505588531494)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.832311749458313)
# लड़की एक बच्चे को ले जा रही है। Score: 0.8303087949752808)
# एक आदमी खाना खा रहा है। Score: 0.8284912109375)
#
# ======================
# 5. Query: दो आदमियों ने गाड़ियों को जंगल में धकेला।
#
# Top 5 most similar sentences in corpus:
# दो आदमियों ने गाड़ियों को जंगल में धकेला। Score: 1.0)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8355227708816528)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.7969417572021484)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.7906560301780701)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.7823730111122131)
#
# ======================
# 6. Query: एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.9999995231628418)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.9131028652191162)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8853156566619873)
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.8563793301582336)
# लड़की एक बच्चे को ले जा रही है। Score: 0.8323653936386108)
#
# ======================
# 7. Query: एक बंदर ढोल बजा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 1.0)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8595538139343262)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.835671067237854)
# एक महिला वायलिन बजा रही है। Score: 0.8327503800392151)
# एक आदमी खाना खा रहा है। Score: 0.8233562707901001)
#
# ======================
# 8. Query: एक बंदर गाना गा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक बंदर ढोल बजा रहा है। Score: 0.8307220935821533)
# एक महिला वायलिन बजा रही है। Score: 0.8140532970428467)
# एक आदमी खाना खा रहा है। Score: 0.7904139757156372)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.7432605028152466)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.7364012002944946)
#
# ======================
# 9. Query: एक बंदर खाना खा रहा है।
#
# Top 5 most similar sentences in corpus:
# एक आदमी खाना खा रहा है। Score: 0.9418457746505737)
# एक बंदर ढोल बजा रहा है। Score: 0.8716267347335815)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8451405763626099)
# एक महिला वायलिन बजा रही है। Score: 0.8342132568359375)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.8009424209594727)
#
# ======================
# 10. Query: एक चीता अपने शिकार के पीछे भाग रहा है।
#
# Top 5 most similar sentences in corpus:
# एक चीता अपने शिकार के पीछे भाग रहा है। Score: 0.9999999403953552)
# एक आदमी रोटी का टुकड़ा खा रहा है। Score: 0.8989200592041016)
# एक आदमी घोड़े की सवारी कर रहा है। Score: 0.8981736898422241)
# एक आदमी सफेद घोड़े पर एक बंद जमीन पर सवार है। Score: 0.8563791513442993)
# लड़की एक बच्चे को ले जा रही है। Score: 0.8541032075881958)
#
# ======================
# 11. Query: सेब
#
# Top 5 most similar sentences in corpus:
# सेब Score: 0.9999998211860657)
# understanding Score: 0.8021702170372009)
# आम Score: 0.7707819938659668)
# apple Score: 0.7442677617073059)
# mango Score: 0.7091531753540039)
#
# ======================
# 12. Query: आम
#
# Top 5 most similar sentences in corpus:
# आम Score: 0.9999994039535522)
# mango Score: 0.8797168731689453)
# apple Score: 0.8098050355911255)
# सेब Score: 0.7707820534706116)
# understanding Score: 0.7377674579620361)
#
# ======================
# 13. Query: समझ
#
# Top 5 most similar sentences in corpus:
# समझ Score: 1.0000004768371582)
# सेब Score: 0.6790438890457153)
# understanding Score: 0.6454148292541504)
# आम Score: 0.6042924523353577)
# apple Score: 0.5845255851745605)
#
# ======================
# 14. Query: Is monkey an animal?
#
# Top 5 most similar sentences in corpus:
# A man is riding a horse. Score: 0.7280466556549072)
# A man is eating food. Score: 0.7259581089019775)
# A monkey is playing drums. Score: 0.7151490449905396)
# A woman is playing violin. Score: 0.6726039052009583)
# A man is eating a piece of bread. Score: 0.6513872146606445)

# %% [markdown]
#  *The issue with multilingual BERT (mBERT) as well as with XLM-RoBERTa is that those produce rather bad sentence representation out-of-the-box. Further, the vectors spaces between languages are not aligned, i.e., the sentences with the same content in different languages would be mapped to different locations in the vector space.*
